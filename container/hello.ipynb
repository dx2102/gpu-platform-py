# %%
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import matplotlib.pyplot as plt

size = 10
img = np.random.randint(0, 4, (size, size, 1), dtype=np.uint8)

plt.axis('off')
plt.imshow(img, cmap='gray')
plt.show()
